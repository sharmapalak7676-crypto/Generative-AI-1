# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmapalak7676-crypto/Generative-AI-1/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2652992662.py in <cell line: 0>()
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
print(my_sub)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-297017354.py in <cell line: 0>()
# ----> 1 print(my_sub)
#
# NameError: name 'my_sub' is not defined

# %%
#double quotes
my_city =  "solan"
type(my_city)
# Out:
# str

# %%
#triple quotes
my_sentence = '''this is a sentences
with multiple lines'''
type(my_sentence)
# Out:
# str

# %%
my_sub = "Machine learning"
len(my_sub)
# Out:
# 16

# %%
my_sub = "Machine learning"
my_sub[0]
# Out:
# 'M'

# %%
my_sub[-16]
# Out:
# 'M'
